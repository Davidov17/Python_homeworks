# %%
people = [
    {"ism": "Ali", "yosh": 20, "imtiyoz": False},
    {"ism": "Vali", "yosh": 65, "imtiyoz": False},
    {"ism": "Guli", "yosh": 18, "imtiyoz": True}
]

new_list = []
for i in range(len(people)):
    if people[i]['yosh']>=65:
        new_list.append(people[i]['ism'])
for j in range(len(people)):
    if people[j]['imtiyoz']==True:
        new_list.append(people[j]['ism'])
new_list
for k in range(len(people)):
    if not people[k]['ism'] in new_list:
        new_list.append(people[k]['ism'])
new_list
# Out:
# ['Vali', 'Guli', 'Ali']

# %%
import pandas as pd
df = pd.DataFrame({
    "receipt_no": [1001,1002,1003,1004,1006,1006,1007,1008,1009,1010],
    "amount":     [  10,  15,  20,   5,  50,  50,  10,  25,  30,  40]
})
df
for i in range(df['receipt_no'].min(), df['receipt_no'].max()+1):
    if i not in df['receipt_no'].values:
        print(i)
# Out:
# 1005

# %%
import pandas as pd
recipe = pd.DataFrame({
    "recipe_name": ["hotdog","hotdog","pilov","pilov","pilov","pizza","pizza","pizza"],
    "ingredient_id": [1,2,3,4,5,6,7,8],
    "ingredient_name": ["sausage","bread","rice","carrot","meat","flour","tomato","cheese"]
})
fridge = pd.DataFrame({
    "ingredient_id": [1,2,3,4,6],
    "ingredient_name": ["sausage","bread","rice","carrot","flour"]
})

# %%
fridge_set = set(fridge['ingredient_name'])

# %%
valid_recipes = []

# %%
recipe
# Out:
#   recipe_name  ingredient_id ingredient_name
# 0      hotdog              1         sausage
# 1      hotdog              2           bread
# 2       pilov              3            rice
# 3       pilov              4          carrot
# 4       pilov              5            meat
# 5       pizza              6           flour
# 6       pizza              7          tomato
# 7       pizza              8          cheese

# %%
fridge
# Out:
#    ingredient_id ingredient_name
# 0              1         sausage
# 1              2           bread
# 2              3            rice
# 3              4          carrot
# 4              6           flour

# %%
n = int(input("enter the number of ingredients: "))
if n%2==0 and n!=0:
    print('Even')
elif n%2!=0:
    print('Odd')
elif n==0:
    print('Zero')
# Out:
# Zero

# %%
string = str(input("enter a string: "))
reversed = string[::-1]
print(reversed)
# Out:
# dlroW ,olleH

# %%
limit = int(input("enter the limit: "))
i = 0
while i<limit:
